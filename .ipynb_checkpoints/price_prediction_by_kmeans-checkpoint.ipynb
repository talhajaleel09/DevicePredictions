# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("train - train.csv")
df
# Out:
#       battery_power  blue  clock_speed  dual_sim    fc  four_g  int_memory  \
# 0               842     0          2.2         0   1.0     0.0         7.0
# 1              1021     1          0.5         1   0.0     1.0        53.0
# 2               563     1          0.5         1   2.0     1.0        41.0
# 3               615     1          2.5         0   0.0     0.0        10.0
# 4              1821     1          1.2         0  13.0     1.0        44.0
# ...             ...   ...          ...       ...   ...     ...         ...
# 1995            794     1          0.5         1   0.0     1.0         2.0
# 1996           1965     1          2.6         1   0.0     0.0        39.0
# 1997           1911     0          0.9         1   1.0     1.0        36.0
# 1998           1512     0          0.9         0   4.0     1.0        46.0
# 1999            510     1          2.0         1   5.0     1.0        45.0
#
# ...

# %%
# Shape of data
df.shape
#2000 rows and 21 columns
# Out:
# (2000, 21)

# %% [markdown]
# ### Finding Missing Values

# %%
missing_data = df[df.isnull().any(axis=1)]
missing_data
# Out:
#      battery_power  blue  clock_speed  dual_sim   fc  four_g  int_memory  \
# 157           1224     0          0.5         0  NaN     NaN         NaN
# 158           1356     0          2.8         0  NaN     NaN         NaN
# 217           1336     0          0.9         0  5.0     1.0        17.0
# 261            728     0          2.7         1  NaN     NaN         NaN
# 276           1662     0          0.5         0  NaN     NaN         NaN
# 292           1995     1          1.9         0  6.0     0.0         9.0
# 293           1517     0          0.5         0  6.0     1.0        48.0
# 341            811     1          2.4         1  5.0     1.0         2.0
# 371           1011     0          1.1         0  NaN     NaN         NaN
#
#      m_dep  mobile_wt  n_cores  ...  px_height  px_width     ram  sc_h  sc_w  \
# 157    NaN        NaN      NaN  ...      747.0     826.0   506.0  10.0   0.0
# 158    NaN        NaN      NaN  ...     1612.0    1983.0  3702.0  17.0   0.0
# ...

# %% [markdown]
# ### Handling Missing Values

# %%
from sklearn.impute import KNNImputer

# %%
df_filled = df.copy()

# Identify columns with missing values (NaN)
columns_with_missing_values = df_filled.columns[df_filled.isnull().any(axis=0)]

# Remove 'price_range' from columns_with_missing_values (assuming it contains missing values, if not, adjust accordingly)
columns_with_missing_values = columns_with_missing_values.drop('price_range', errors='ignore')
columns_with_missing_values
# Out:
# Index(['fc', 'four_g', 'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc',
#        'px_height', 'px_width', 'ram', 'sc_h', 'sc_w'],
#       dtype='object')

# %%
# Apply KNNImputer to fill missing values for columns with missing values

imputer = KNNImputer()

df_filled[columns_with_missing_values] = imputer.fit_transform(df_filled[columns_with_missing_values])

df_filled.iloc[[157, 158, 217, 261]]
# Out:
#      battery_power  blue  clock_speed  dual_sim   fc  four_g  int_memory  \
# 157           1224     0          0.5         0  1.8     0.8        30.6
# 158           1356     0          2.8         0  3.0     0.4        44.2
# 217           1336     0          0.9         0  5.0     1.0        17.0
# 261            728     0          2.7         1  6.6     0.4        29.8
#
#      m_dep  mobile_wt  n_cores  ...  px_height  px_width     ram  sc_h  sc_w  \
# 157   0.44      132.8      4.6  ...      747.0     826.0   506.0  10.0   0.0
# 158   0.34      139.0      3.2  ...     1612.0    1983.0  3702.0  17.0   0.0
# 217   0.38      194.0      5.0  ...       55.0     583.0  1869.0  13.0   1.0
# 261   0.50      130.6      5.0  ...      604.2    1649.2  2433.6   5.0   1.0
#
#      talk_time  three_g  touch_screen  wifi  price_range
# 157         11        1             1     1            0
# 158         19        0             0     0            3
# ...

# %% [markdown]
# #### Missing Values are filled above now replacing new df into old df

# %%
df = df_filled
df
# Out:
#       battery_power  blue  clock_speed  dual_sim    fc  four_g  int_memory  \
# 0               842     0          2.2         0   1.0     0.0         7.0
# 1              1021     1          0.5         1   0.0     1.0        53.0
# 2               563     1          0.5         1   2.0     1.0        41.0
# 3               615     1          2.5         0   0.0     0.0        10.0
# 4              1821     1          1.2         0  13.0     1.0        44.0
# ...             ...   ...          ...       ...   ...     ...         ...
# 1995            794     1          0.5         1   0.0     1.0         2.0
# 1996           1965     1          2.6         1   0.0     0.0        39.0
# 1997           1911     0          0.9         1   1.0     1.0        36.0
# 1998           1512     0          0.9         0   4.0     1.0        46.0
# 1999            510     1          2.0         1   5.0     1.0        45.0
#
# ...

# %%
df[df.isnull().any(axis=1)]
# Now no value is missing
# Out:
# Empty DataFrame
# Columns: [battery_power, blue, clock_speed, dual_sim, fc, four_g, int_memory, m_dep, mobile_wt, n_cores, pc, px_height, px_width, ram, sc_h, sc_w, talk_time, three_g, touch_screen, wifi, price_range]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# ## Applying Feature Engineering

# %%
# except using 21 columns we only focus on main columns which plays vital role for price range

# %%
from sklearn.feature_selection import SelectKBest, chi2

# %%
# Assuming 'df_filled' contains your DataFrame with missing values filled
X = df_filled.drop('price_range', axis=1)  # Features (excluding the target variable)
y = df_filled['price_range']  # Target variable
X
# Out:
#       battery_power  blue  clock_speed  dual_sim    fc  four_g  int_memory  \
# 0               842     0          2.2         0   1.0     0.0         7.0
# 1              1021     1          0.5         1   0.0     1.0        53.0
# 2               563     1          0.5         1   2.0     1.0        41.0
# 3               615     1          2.5         0   0.0     0.0        10.0
# 4              1821     1          1.2         0  13.0     1.0        44.0
# ...             ...   ...          ...       ...   ...     ...         ...
# 1995            794     1          0.5         1   0.0     1.0         2.0
# 1996           1965     1          2.6         1   0.0     0.0        39.0
# 1997           1911     0          0.9         1   1.0     1.0        36.0
# 1998           1512     0          0.9         0   4.0     1.0        46.0
# 1999            510     1          2.0         1   5.0     1.0        45.0
#
# ...

# %%
# Initialize SelectKBest with chi2 score function
selector = SelectKBest(score_func=chi2, k=10)
selector
# Out:
# SelectKBest(score_func=<function chi2 at 0x00000229CC689DA0>)

# %%
# Fit selector to features and target
selector.fit(X, y)
# Out:
# SelectKBest(score_func=<function chi2 at 0x00000229CC689DA0>)

# %%
# Get the indices of the selected features
selected_indices = selector.get_support(indices=True)

# %%
selected_indices
# Out:
# array([ 0,  4,  6,  8, 10, 11, 12, 13, 15, 16], dtype=int64)

# %% [markdown]
# ## Selected Columns

# %%
# Get the names of the selected columns
selected_columns = X.columns[selected_indices]
selected_columns
# Out:
# Index(['battery_power', 'fc', 'int_memory', 'mobile_wt', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_w', 'talk_time'],
#       dtype='object')

# %% [markdown]
# ## Converting to Vector

# %%
from sklearn import preprocessing

# %%
X.columns[selected_indices]
# Out:
# Index(['battery_power', 'fc', 'int_memory', 'mobile_wt', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_w', 'talk_time'],
#       dtype='object')

# %%
type(X.columns[selected_indices])
# Out:
# pandas.core.indexes.base.Index

# %%
selected_df =  pd.DataFrame(X, columns=X.columns[selected_indices])
selected_df
# Out:
#       battery_power    fc  int_memory  mobile_wt    pc  px_height  px_width  \
# 0               842   1.0         7.0      188.0   2.0       20.0     756.0
# 1              1021   0.0        53.0      136.0   6.0      905.0    1988.0
# 2               563   2.0        41.0      145.0   6.0     1263.0    1716.0
# 3               615   0.0        10.0      131.0   9.0     1216.0    1786.0
# 4              1821  13.0        44.0      141.0  14.0     1208.0    1212.0
# ...             ...   ...         ...        ...   ...        ...       ...
# 1995            794   0.0         2.0      106.0  14.0     1222.0    1890.0
# 1996           1965   0.0        39.0      187.0   3.0      915.0    1965.0
# 1997           1911   1.0        36.0      108.0   3.0      868.0    1632.0
# 1998           1512   4.0        46.0      145.0   5.0      336.0     670.0
# 1999            510   5.0        45.0      168.0  16.0      483.0     754.0
#
#          ram  sc_w  talk_time
# ...

# %%
selected_df_norm = preprocessing.normalize(selected_df)
selected_df_norm
# Out:
# array([[3.01212062e-01, 3.57734040e-04, 2.50413828e-03, ...,
#         9.11864069e-01, 2.50413828e-03, 6.79694677e-03],
#        [2.85856828e-01, 0.00000000e+00, 1.48387972e-02, ...,
#         7.36620289e-01, 8.39931915e-04, 1.95984113e-03],
#        [1.64910343e-01, 5.85827153e-04, 1.20094566e-02, ...,
#         7.62454039e-01, 5.85827153e-04, 2.63622219e-03],
#        ...,
#        [4.71499649e-01, 2.46729277e-04, 8.88225398e-03, ...,
#         7.54251400e-01, 2.46729277e-04, 1.23364639e-03],
#        [7.93950343e-01, 2.10039773e-03, 2.41545739e-02, ...,
#         4.56311407e-01, 5.25099433e-03, 9.97688923e-03],
#        [1.25740104e-01, 1.23274611e-03, 1.10947150e-02, ...,
#         9.66226404e-01, 9.86196891e-04, 4.93098445e-04]])

# %% [markdown]
# ### Dividing rows into 2 separate vectors

# %%
selected_df_norm.shape
# Out:
# (2000, 10)

# %%
train_selected_vector = selected_df_norm[:1000]
train_selected_vector
# Out:
# array([[3.01212062e-01, 3.57734040e-04, 2.50413828e-03, ...,
#         9.11864069e-01, 2.50413828e-03, 6.79694677e-03],
#        [2.85856828e-01, 0.00000000e+00, 1.48387972e-02, ...,
#         7.36620289e-01, 8.39931915e-04, 1.95984113e-03],
#        [1.64910343e-01, 5.85827153e-04, 1.20094566e-02, ...,
#         7.62454039e-01, 5.85827153e-04, 2.63622219e-03],
#        ...,
#        [5.69962622e-01, 0.00000000e+00, 1.01397845e-02, ...,
#         6.45210496e-01, 6.40407440e-03, 6.40407440e-03],
#        [3.83989371e-01, 2.79671792e-04, 8.11048198e-03, ...,
#         7.69656773e-01, 5.59343585e-04, 1.95770255e-03],
#        [4.09882915e-01, 6.91980160e-04, 4.61320107e-03, ...,
#         8.92193087e-01, 2.30660053e-04, 1.61462037e-03]])

# %%
test_selected_vector = selected_df_norm[1001:2000]
test_selected_vector
# Out:
# array([[7.58470234e-01, 2.48841940e-03, 2.83679812e-02, ...,
#         4.71306635e-01, 1.99073552e-03, 7.96294209e-03],
#        [2.99888671e-01, 7.04239541e-03, 2.93433142e-02, ...,
#         8.70909565e-01, 4.10806399e-03, 4.69493027e-03],
#        [5.54759599e-01, 1.18707475e-03, 1.82018128e-02, ...,
#         1.37304979e-01, 0.00000000e+00, 4.74829899e-03],
#        ...,
#        [4.71499649e-01, 2.46729277e-04, 8.88225398e-03, ...,
#         7.54251400e-01, 2.46729277e-04, 1.23364639e-03],
#        [7.93950343e-01, 2.10039773e-03, 2.41545739e-02, ...,
#         4.56311407e-01, 5.25099433e-03, 9.97688923e-03],
#        [1.25740104e-01, 1.23274611e-03, 1.10947150e-02, ...,
#         9.66226404e-01, 9.86196891e-04, 4.93098445e-04]])

# %%
from sklearn.decomposition import PCA

# Assuming X is your data with 10 columns
# Convert the DataFrame to a NumPy array
X = test_selected_vector
Y = train_selected_vector

# Create an instance of PCA with 1 component
x_pca = PCA(n_components=2)
y_pca = PCA(n_components=2)

# Fit PCA to the data and transform the data
X_reduced = pca.fit_transform(X)
Y_reduced = pca.fit_transform(Y)

# Convert the reduced data back to a DataFrame
x_df_reduced = pd.DataFrame(X_reduced, columns=['X','Y'])
y_df_reduced = pd.DataFrame(Y_reduced, columns=['X','Y'])

# Print the first few rows of the reduced DataFrame
print(df_reduced)
print(X_reduced)
# Out:
#             X         Y
# 0    0.248005  0.262513
# 1   -0.285065 -0.005345
# 2    0.611175 -0.119833
# 3   -0.416655  0.060960
# 4   -0.129724 -0.150817
# ..        ...       ...
# 994  0.457058 -0.357707
# 995  0.169185  0.017263
# 996 -0.078465  0.044913
# 997  0.253511  0.334726
# 998 -0.494696 -0.067641
#
# [999 rows x 2 columns]
# [[ 0.24800488  0.26251261]
#  [-0.28506512 -0.0053449 ]
#  [ 0.61117501 -0.11983332]
#  ...
#  [-0.07846452  0.04491286]
#  [ 0.25351086  0.33472641]
#  [-0.49469607 -0.06764126]]

# %% [markdown]
# ## Applying K- Clustering

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
kmeans = KMeans(n_clusters = 4, random_state = 0, n_init='auto')
kmeans.fit(Y_reduced)
# Out:
# KMeans(n_clusters=4, random_state=0)

# %%
# import seaborn as sns

# sns.scatterplot(data = df, x = "battery_power", y = 'price_range', hue = 'talk_time')

# %%
test_predict = kmeans.fit_predict(X_reduced)
test_predict
# Out:
# array([0, 2, 3, 2, 1, 0, 3, 1, 0, 1, 3, 1, 0, 0, 2, 1, 1, 1, 0, 2, 2, 1,
#        0, 1, 0, 1, 1, 1, 2, 2, 2, 0, 1, 0, 0, 2, 3, 3, 1, 3, 1, 1, 0, 1,
#        2, 2, 2, 2, 1, 2, 1, 2, 1, 0, 0, 2, 1, 2, 0, 2, 0, 2, 0, 3, 3, 2,
#        0, 0, 3, 3, 0, 1, 0, 2, 3, 3, 2, 2, 0, 1, 1, 2, 1, 2, 2, 0, 1, 0,
#        2, 2, 0, 1, 0, 3, 1, 1, 2, 2, 0, 2, 3, 3, 1, 2, 0, 3, 1, 2, 2, 2,
#        2, 2, 2, 2, 2, 0, 2, 1, 2, 2, 2, 1, 0, 1, 2, 2, 1, 0, 2, 2, 1, 2,
#        0, 3, 2, 1, 3, 2, 1, 2, 1, 2, 2, 2, 1, 2, 0, 1, 0, 2, 2, 1, 2, 2,
#        2, 2, 0, 1, 3, 2, 2, 1, 3, 1, 0, 2, 2, 1, 2, 3, 2, 2, 1, 1, 2, 2,
#        2, 0, 2, 2, 3, 3, 3, 2, 1, 2, 0, 2, 2, 0, 1, 2, 3, 3, 1, 2, 1, 2,
#        2, 1, 2, 1, 2, 2, 2, 2, 1, 2, 0, 2, 3, 2, 1, 1, 2, 1, 2, 1, 0, 2,
#        1, 2, 1, 3, 3, 2, 2, 3, 2, 3, 3, 2, 2, 2, 0, 0, 0, 1, 1, 0, 1, 2,
#        1, 1, 3, 2, 3, 0, 1, 2, 2, 2, 3, 3, 2, 2, 2, 2, 0, 0, 2, 1, 1, 1,
#        1, 3, 3, 1, 2, 1, 1, 3, 2, 2, 2, 2, 0, 3, 1, 3, 1, 1, 1, 1, 2, 3,
# ...

# %%
test_predict.shape
# Out:
# (999,)

# %%
# plt.scatter(cluster_centers[:, 0], cluster_centers[:, 1], marker='o', s=200, c='red', label='Cluster Centers')
# plt.xlabel('Feature 1')
# plt.ylabel('Feature 2')
# plt.title('KMeans Clustering')
# plt.legend()
# plt.show()

# %% [markdown]
# ### Decreasing Dimensions

# %%
# df['X'] = x_df_reduced['X']
# df['Y'] = x_df_reduced['Y']
x_df_reduced['predict'] = test_predict
x_df_reduced
# Out:
#             X         Y  predict
# 0    0.248005  0.262513        0
# 1   -0.285065 -0.005345        2
# 2    0.611175 -0.119833        3
# 3   -0.416655  0.060960        2
# 4   -0.129724 -0.150817        1
# ..        ...       ...      ...
# 994  0.457058 -0.357707        3
# 995  0.169185  0.017263        0
# 996 -0.078465  0.044913        1
# 997  0.253511  0.334726        0
# 998 -0.494696 -0.067641        2
#
# [999 rows x 3 columns]

# %%
import seaborn as sns

sns.scatterplot(data = x_df_reduced, x = "X", y = 'Y', hue = 'predict')

# Y as Batter Power and in X contains reduced columns
# Out:
# <Axes: xlabel='X', ylabel='Y'>

# %%
cluster_centers = kmeans.cluster_centers_

# %% [markdown]
# ## Visualizing Cluster and Centroids

# %%
plt.figure(figsize=(8, 6))

plt.scatter(x=X_reduced[:1000, 0], y=X_reduced[:1000, 1],c=y_predict[:1000],  cmap='viridis', alpha=0.5)

plt.scatter(cluster_centers[:, 0], cluster_centers[:, 1], marker='o', s=100, c='red', label='Centroids')

plt.title('KMeans Clustering')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.show()

# %%
X_reduced[:, 0].shape

# %%
X_reduced[:, 1].shape

# %%
kmeans.cluster_centers_.shape
# Out:
# (4, 2)

# %%
kmeans.cluster_centers_
# Out:
# array([[ 0.27605571,  0.2128729 ],
#        [-0.02573051, -0.12457109],
#        [-0.26133327,  0.05030889],
#        [ 0.42035192, -0.16281846]])
